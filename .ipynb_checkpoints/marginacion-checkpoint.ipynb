# %% [markdown]
# Jerónimo Aranda Barois 150344 a 20 de agosto de 2019
# # Análisis exploratorio de datos de marginación
#
# Primero importamos los paquetes más importantes:

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from sklearn import linear_model
import seaborn as sns

# %% [markdown]
# Nos aseguramos que el archivo de datos se encuentre en el mismo directorio en el que este notebook se encuentra:

# %%
os.listdir()
# Out:
# ['indice_marginacion.csv', 'marginacion.ipynb', '.ipynb_checkpoints']

# %% [markdown]
# Procedemos a leer el archivo csv de datos y a visualizar sus primeros 5 elementos junto con algunas de sus columnas.

# %%
df=pd.read_csv('indice_marginacion.csv')
df.head()
# Out:
#   CVE_ENT             ENT CVE_MUN                  MUN  POB_TOT VP ANALF  \
# 0       1  Aguascalientes    1001       Aguascalientes   877190  -  2.06
# 1       1  Aguascalientes    1005          Jes˙s MarÌa   120405  -  3.26
# 2       1  Aguascalientes    1003             Calvillo    56048  -   4.8
# 3       1  Aguascalientes    1007      RincÛn de Romos    53866  -  3.53
# 4       1  Aguascalientes    1006  PabellÛn de Arteaga    46473  -  3.41
#
#    SPRIM OVSDE OVSEE  ...  PL<5000  PO2SM OVSD OVSDSE      IM        GM  \
# 0   9.54  0.31  0.16  ...     8.73  31.13    -      -  -1.676  Muy bajo
# 1  13.73  0.44  0.37  ...    45.17  33.77    -      -  -1.256  Muy bajo
# 2  24.18  0.55  0.41  ...    50.76  61.95    -      -  -0.698      Bajo
# 3  14.75  1.97  0.52  ...    43.06  43.44    -      -  -1.045      Bajo
# 4   14.9     1  0.42  ...     31.6  41.48    -      -  -1.129  Muy bajo
#
#   IND0A100 LUG_NAC LUGAR_EST   A—O
# 0        -    2408        11  2015
# 1        -    2229        10  2015
# 2        -    1799         5  2015
# 3        -    2090         7  2015
# 4        -    2153         8  2015
#
# [5 rows x 23 columns]

# %% [markdown]
# Podemos ver que tiene valores vacíos definidos por un guión además de valores 'N. D.', procedemos a marcarlos para que python los reconozca como valores faltantes.

# %%
missing_values = ["-",'N. D.']
df = pd.read_csv("indice_marginacion.csv", na_values = missing_values)
df.head()
# Out:
#    CVE_ENT             ENT  CVE_MUN                  MUN  POB_TOT  VP  ANALF  \
# 0      1.0  Aguascalientes   1001.0       Aguascalientes   877190 NaN   2.06
# 1      1.0  Aguascalientes   1005.0          Jes˙s MarÌa   120405 NaN   3.26
# 2      1.0  Aguascalientes   1003.0             Calvillo    56048 NaN   4.80
# 3      1.0  Aguascalientes   1007.0      RincÛn de Romos    53866 NaN   3.53
# 4      1.0  Aguascalientes   1006.0  PabellÛn de Arteaga    46473 NaN   3.41
#
#    SPRIM  OVSDE  OVSEE  ...   PL<5000  PO2SM  OVSD  OVSDSE     IM        GM  \
# 0   9.54   0.31   0.16  ...      8.73  31.13   NaN     NaN -1.676  Muy bajo
# 1  13.73   0.44   0.37  ...     45.17  33.77   NaN     NaN -1.256  Muy bajo
# 2  24.18   0.55   0.41  ...     50.76  61.95   NaN     NaN -0.698      Bajo
# 3  14.75   1.97   0.52  ...     43.06  43.44   NaN     NaN -1.045      Bajo
# 4  14.90   1.00   0.42  ...     31.60  41.48   NaN     NaN -1.129  Muy bajo
#
#   IND0A100  LUG_NAC LUGAR_EST   A—O
# 0      NaN   2408.0      11.0  2015
# 1      NaN   2229.0      10.0  2015
# 2      NaN   1799.0       5.0  2015
# 3      NaN   2090.0       7.0  2015
# 4      NaN   2153.0       8.0  2015
#
# [5 rows x 23 columns]

# %% [markdown]
# A continuación veremos los últimos 5 elementos del data frame, parece que están ordenados por entidad.

# %%
df.tail()
# Out:
#        CVE_ENT        ENT  CVE_MUN  \
# 14640     32.0  Zacatecas  32028.0
# 14641     32.0  Zacatecas  32030.0
# 14642     32.0  Zacatecas  32041.0
# 14643     32.0  Zacatecas  32015.0
# 14644     32.0  Zacatecas  32043.0
#
#                                                      MUN  POB_TOT  VP  ANALF  \
# 14640                                  Mezquital del Oro     3519 NaN  13.88
# 14641                                              Momax     3486 NaN  10.38
# 14642   El Salvador                                  ...     3353 NaN  23.63
# 14643                              General JoaquÌn Amaro     3242 NaN  11.95
# 14644                                         Susticac·n     1632 NaN  15.54
#
#        SPRIM  OVSDE  OVSEE  ...   PL<5000  PO2SM  OVSD  OVSDSE     IM     GM  \
# 14640  60.20  65.51  34.90  ...     100.0  71.14   NaN     NaN  0.199   Alto
# 14641  57.04  41.38  12.99  ...     100.0  65.91   NaN     NaN -0.690   Bajo
# 14642  67.41  55.79  27.96  ...     100.0  88.45   NaN     NaN  0.219   Alto
# 14643  65.96  78.22  11.35  ...     100.0  84.60   NaN     NaN  0.077   Alto
# 14644  70.08  52.14  16.67  ...     100.0  76.58   NaN     NaN -0.050  Medio
#
#       IND0A100  LUG_NAC LUGAR_EST   A—O
# 14640      NaN   1033.0       9.0  1990
# 14641      NaN   1755.0      41.0  1990
# 14642      NaN   1013.0       7.0  1990
# 14643      NaN   1130.0      11.0  1990
# 14644      NaN   1234.0      14.0  1990
#
# [5 rows x 23 columns]

# %% [markdown]
# Ahora averigüemos la cantidad de registros y columnas que el data frame posee:

# %%
df.shape
# Out:
# (14645, 23)

# %% [markdown]
# Es decir posee 14645 registros y de cada uno hay 23 columnas diferentes. Procedamos a ver el nombre de las 23 columnas:

# %%
df.columns
# Out:
# Index(['CVE_ENT', 'ENT', 'CVE_MUN', 'MUN', 'POB_TOT', 'VP', 'ANALF', 'SPRIM',
#        'OVSDE', 'OVSEE', 'OVSAE', 'VHAC', 'OVPT', 'PL<5000', 'PO2SM', 'OVSD',
#        'OVSDSE', 'IM', 'GM', 'IND0A100', 'LUG_NAC', 'LUGAR_EST', 'A—O'],
#       dtype='object')

# %% [markdown]
# En la siguiente línea podemos ver los tipos de las variables en cada columna.

# %%
df.dtypes
# Out:
# CVE_ENT      float64
# ENT           object
# CVE_MUN      float64
# MUN           object
# POB_TOT        int64
# VP           float64
# ANALF        float64
# SPRIM        float64
# OVSDE        float64
# OVSEE        float64
# OVSAE        float64
# VHAC         float64
# OVPT         float64
# PL<5000      float64
# PO2SM        float64
# OVSD         float64
# OVSDSE        object
# IM           float64
# GM            object
# IND0A100     float64
# LUG_NAC      float64
# LUGAR_EST    float64
# A—O            int64
# dtype: object

# %% [markdown]
# A continuación se hace una gráfica de todas las observaciones de la población por municipios por estado.

# %%
df.plot.scatter(x='CVE_ENT',y='POB_TOT',c='IM',colormap='viridis')

# %% [markdown]
# Se alcanza a ver un poco la distribución de la población en cada uno de los estados. Además que el indice de marginación es más alto en los municipios que tienen poblaciones más pequeñas.

# %% [markdown]
# ### Muestra de 600 observaciones.

# %% [markdown]
# En esta parte obtendremos una muestra de 600 observaciones:

# %%
df_sample=df.sample(n=600,random_state=42)
print(df_sample.shape)
df_sample.head()
# Out:
# (600, 23)
#        CVE_ENT                   ENT  CVE_MUN                    MUN  POB_TOT  \
# 4965       5.0  Coahuila de Zaragoza   5031.0       San Buenaventura    19620
# 12450      8.0             Chihuahua   8055.0                Rosales    14154
# 6363      20.0                Oaxaca  20241.0     San MartÌn Lachil·      979
# 8882      20.0                Oaxaca  20416.0   Santa MarÌa Ixcatl·n      594
# 8294      18.0               Nayarit  18008.0                Xalisco    37664
#
#        VP  ANALF  SPRIM  OVSDE  OVSEE  ...  PL<5000  PO2SM OVSD  OVSDSE  \
# 4965  NaN   3.05  13.87   0.44   0.73  ...     8.51  40.02  NaN     NaN
# 12450 NaN   7.38  46.88  19.55  10.11  ...   100.00  71.01  NaN     NaN
# 6363  NaN  26.94  46.85   0.00   0.41  ...   100.00  80.45  NaN     NaN
# 8882  NaN   27.1  53.07    NaN   9.09  ...   100.00  92.88  NaN    7.24
# 8294  NaN   6.78  27.43    NaN   1.98  ...    37.03  53.79  NaN    3.24
#
#           IM        GM IND0A100  LUG_NAC LUGAR_EST   A—O
# 4965  -1.682  Muy bajo      NaN   2378.0      31.0  2005
# 12450 -0.909      Bajo      NaN   1919.0      34.0  1990
# 6363   0.307      Alto      NaN    900.0     364.0  2005
# 8882   0.679      Alto      NaN    621.0     264.0  2000
# 8294  -1.292  Muy bajo      NaN   2204.0      18.0  2000
#
# [5 rows x 23 columns]

# %% [markdown]
# Y con ella haremos una grafica de caja y brazos para algunas variables:

# %%
df_sample.boxplot(column=['OVSD','PL<5000'])

# %%
correlation = df.corr(method='pearson')
columns = correlation.nlargest(11, 'IM').index
correlation
# Out:
#             CVE_ENT   CVE_MUN   POB_TOT        VP     ANALF     SPRIM  \
# CVE_ENT    1.000000  0.999838 -0.125683 -0.122378  0.023464  0.064218
# CVE_MUN    0.999838  1.000000 -0.128043 -0.124686  0.028202  0.068065
# POB_TOT   -0.125683 -0.128043  1.000000  0.997011 -0.028879 -0.040782
# VP        -0.122378 -0.124686  0.997011  1.000000 -0.236990       NaN
# ANALF      0.023464  0.028202 -0.028879 -0.236990  1.000000  0.852570
# SPRIM      0.064218  0.068065 -0.040782       NaN  0.852570  1.000000
# SPRIM      0.762075       NaN  0.727426  0.881067 -0.730311  -0.065312
# OVSDE      0.469835       NaN  0.384512  0.455490 -0.379904  -0.092463
# OVSEE      0.398043  0.457387  0.509275  0.576833 -0.476881  -0.171489
# OVSAE      0.429858  0.523720  0.582577  0.577784 -0.568906  -0.092386
# VHAC       0.687510       NaN  0.587605  0.717558 -0.587371  -0.050759
# OVPT       0.638958       NaN  0.665742  0.677276 -0.658197   0.049347
# PL<5000    0.545000       NaN  0.635173  0.640981 -0.649236   0.045230
# PO2SM      1.000000       NaN  0.724098  0.857393 -0.749594   0.116062
# OVSD            NaN  1.000000  0.831324       NaN -0.847526        NaN
# IM         0.724098  0.831324  1.000000  1.000000 -0.982800  -0.056544
# IND0A100   0.857393       NaN  1.000000  1.000000 -0.981549        NaN
# LUG_NAC   -0.749594 -0.847526 -0.982800 -0.981549  1.000000   0.028712
# LUGAR_EST  0.116062       NaN -0.056544       NaN  0.028712   1.000000
# A—O       -0.404406       NaN -0.000003       NaN  0.012622  -0.001757
#
#                 A—O
# CVE_ENT   -0.000422
# CVE_MUN   -0.000443
# POB_TOT    0.013092
# VP              NaN
# ANALF     -0.305636
# SPRIM     -0.564955
# OVSDE     -0.692865
# OVSEE     -0.457328
# OVSAE     -0.361077
# VHAC      -0.625999
# OVPT      -0.500991
# PL<5000   -0.052595
# PO2SM     -0.404406
# OVSD            NaN
# IM        -0.000003
# IND0A100        NaN
# LUG_NAC    0.012622
# LUGAR_EST -0.001757
# A—O        1.000000

# %%
correlation_map=correlation[columns].loc[columns]
sns.set(font_scale=1.0)
heatmap = sns.heatmap(correlation_map, cbar=True, annot=True, square=True, fmt='.2f', yticklabels=columns.values, xticklabels=columns.values)

plt.show()

# %% [markdown]
# Como la correlación es mayor entre el índice de marginación y ovsd, analf y sprim hagamos los 3 modelos lineales.

# %%
plt.scatter(x=df['OVSD'],y=df['IM'])
df1=df[['OVSD','IM']].dropna()
X=np.array([df1['OVSD']])
y=df1['IM'].values
lm = linear_model.LinearRegression()
model = lm.fit(X.T,y)
x=range(100)
Y=model.predict(np.array([x]).T)

plt.plot(x,Y,color='red')

# %% [markdown]
# cuya R^2 es:

# %%
print(lm.score(X.T,y))
# Out:
# 0.6910993101399279

# %%
plt.scatter(x=df['ANALF'],y=df['IM'])
df1=df[['ANALF','IM']].dropna()
X=np.array([df1['ANALF']])
y=df1['IM'].values
lm = linear_model.LinearRegression()
model = lm.fit(X.T,y)
x=range(100)
Y=model.predict(np.array([x]).T)

plt.plot(x,Y,color='red')

# %% [markdown]
# cuya R^2 es:

# %%
print(lm.score(X.T,y))
# Out:
# 0.6704117180641818

# %%
plt.scatter(x=df['SPRIM'],y=df['IM'])
df1=df[['SPRIM','IM']].dropna()
X=np.array([df1['SPRIM']])
y=df1['IM'].values
lm = linear_model.LinearRegression()
model = lm.fit(X.T,y)
x=range(100)
Y=model.predict(np.array([x]).T)

plt.plot(x,Y,color='red')

# %% [markdown]
# cuya R^2 es:

# %%
print(lm.score(X.T,y))
# Out:
# 0.6704117180641818
